# %%
#!/usr/bin/python
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler


class MyHandler(FileSystemEventHandler):
    def on_created(self, event):
        import shutil,os,time
        ct=time.strftime('%Y%m%d',time.localtime())
        if not os.path.exists('/Users/Jackie/Desktop/1025hist/'+ct):
            os.makedirs('/Users/Jackie/Desktop/1025hist/'+ct)
        for root,dirs,files in os.walk('/Users/Jackie/Desktop/1024testdir/'):
            for ele in files:
                if '.csv' in ele:
                    print ele
                    shutil.move('/Users/Jackie/Desktop/1024testdir/'+ele,'/Users/Jackie/Desktop/1025hist/'+ct+'/')
        
        
#         for root,dirs,files in os.walk('/Users/Jackie/Desktop/1024testdir/'):
# #             print files
#             for ele in files:
#                 print ele
#         print "Got it!"


if __name__ == "__main__":
    event_handler = MyHandler()
    observer = Observer()
    observer.schedule(event_handler, path='/Users/Jackie/Desktop/1024testdir/', recursive=False)
    observer.start()

    try:
        while True:
            time.sleep(1)
    except KeyboardInterrupt:
        observer.stop()
    print observer.join()
# Out:
# test.csv
# None

# %%
#!/usr/bin/python
import time
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler


class MyHandler(FileSystemEventHandler):
    def on_created(self, event):
        
        import shutil,os,time
        time.sleep(2)
        import demo1027b
        demo1027b.Demotoday()
        demo1027b.RPy()

        ct=time.strftime('%Y%m%d%H%M',time.localtime())
        if not os.path.exists('/Users/Jackie/Desktop/1025hist/'+ct):
            os.makedirs('/Users/Jackie/Desktop/1025hist/'+ct)
        for root,dirs,files in os.walk('/Users/Jackie/Desktop/1024autotest/infiark1/'):
            for ele in files:
                if '.csv' in ele:
#                     import demo1027a
                    print ele
                    shutil.move('/Users/Jackie/Desktop/1024autotest/infiark1/'+ele,'/Users/Jackie/Desktop/1025hist/'+ct+'/')
        
        
#         for root,dirs,files in os.walk('/Users/Jackie/Desktop/1024testdir/'):
# #             print files
#             for ele in files:
#                 print ele
#         print "Got it!"


if __name__ == "__main__":
    event_handler = MyHandler()
    observer = Observer()
    observer.schedule(event_handler, path='/Users/Jackie/Desktop/1024autotest/infiark1/', recursive=False)
    observer.start()

    try:
        while True:
            time.sleep(3)
    except KeyboardInterrupt:
        observer.stop()
    print observer.join()
# Out:
# 13內湖路一段 　堤頂大道(往北).csv
# 14基湖路     　堤頂大道(往北).csv
# 15基湖路     　堤頂大道(往南).csv
# 18堤頂一段   　台新銀行(往北).csv
# 21堤頂大道     舊宗港墘(往北).csv
# 22堤頂大道   民權東六段(往南).csv
# 23堤頂大道   舊宗路二段(往北).csv
# 28民權東六段   　瑞光街(往西).csv
# 29民權東六段　成功(往東).csv
# 30民權東六段　成功(往西).csv
# None

# %%
import os
for root,dirs,files in os.walk('/Users/Jackie/Desktop/1024autotest/infiark1/'):
    for ele in files:
        print ele
# Out:
# .DS_Store

# %%
import demo1027b
help(demo1027b)
# Out:
# Help on module demo1027b:
#
# NAME
#     demo1027b - # coding: utf-8
#
# FILE
#     /Users/Jackie/Desktop/1024autotest/demo1027b.py
#
# FUNCTIONS
#     Demotoday()
#         # 原始檔更換欄位名稱，及頭尾去掉
#
#     RPy()

# %%
import time
            
ct=time.strftime('%Y%m%d%H%M%S',time.localtime())

print ct
# Out:
# 20161026154441

# %%
import watchdog

help(watchdog.events)
# Out:
# Help on module watchdog.events in watchdog:
#
# NAME
#     watchdog.events
#
# FILE
#     /Users/Jackie/anaconda/lib/python2.7/site-packages/watchdog/events.py
#
# DESCRIPTION
#     :module: watchdog.events
#     :synopsis: File system events and event handlers.
#     :author: yesudeep@google.com (Yesudeep Mangalapilly)
#
#     Event Classes
#     -------------
#     .. autoclass:: FileSystemEvent
#        :members:
#        :show-inheritance:
#        :inherited-members:
#
#     .. autoclass:: FileSystemMovedEvent
#        :members:
#        :show-inheritance:
#
#     .. autoclass:: FileMovedEvent
#        :members:
#        :show-inheritance:
#
#     .. autoclass:: DirMovedEvent
#        :members:
#        :show-inheritance:
#
#     .. autoclass:: FileModifiedEvent
#        :members:
#        :show-inheritance:
#
#     .. autoclass:: DirModifiedEvent
#        :members:
#        :show-inheritance:
#
#     .. autoclass:: FileCreatedEvent
#        :members:
# ...
