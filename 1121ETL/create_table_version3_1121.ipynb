# %%
# coding: utf-8

import time
import shutil
import sys
import io
import os
import csv
import re
import datetime
import mysql.connector
from  mysql.connector import MySQLConnection, Error

# 這麼多defualt是因為如果不重新設定，在使用 reload函數時，print會被印在 terminal上。
default_stdout = sys.stdout
default_stderr = sys.stderr
reload(sys)
sys.stdout = default_stdout
sys.stderr = default_stderr
sys.setdefaultencoding('utf-8')

'''


'''

cs = time.strftime('%Y/%m/%d_%H:%M:%S',time.localtime())
print cs
# 存粹看運算時間
def ETL():
    """
    把最原始得資料拿來做ETL，頭尾不用的去掉，加入新的欄位名稱。
    
    """
    try:
        # create 'clean' folder  if not exist.
        if not os.path.exists('/Users/Jackie/Desktop/1107/clean'):
            os.makedirs('/Users/Jackie/Desktop/1107/clean')
        # from infiark1/ pick only files to do the trick.
        files=[]
        for f in os.listdir('/Users/Jackie/Desktop/1107/'):
            if os.path.isfile('/Users/Jackie/Desktop/1107/' + f):
                files.append(f)
        # chose only the csv files to ETL and rename it.
        # tt=[]
        for f in files:
            if '.csv' in f:

                with io.open('/Users/Jackie/Desktop/1107/' + f, 'r', encoding='utf-8')as rfile:
                    ff=[]
                    for ele in rfile:
                        ff.append(ele)
                    # 檔案名字用VD的編號，從檔案內的第一欄抓出來
                    fname = ff[2:-2][0].split(',')[0] 
                    with io.open('/Users/Jackie/Desktop/1107/clean/' + \
                                 fname + '.csv', 'w', encoding='utf-8') as wfile:
                        wfile.write(u'''EQIPnumber,location,direct,YMD,hour,laneNumber,\
                        addTotal,15Total,truckflow,carflow,scooterflow,avgspeed,avgPercent,avgCarSpace''' + u'\n')
                        
                        for ele in ff[2:-2]:
                            # 去掉檔案裡上下不用的中文敘述，再把平均速度='-1'的值挑掉不要，最後是把原來檔案內的','跟'\n'去掉。
                            if ele.split(',')[-4] == '-1.0':
                                continue
                            # 把datetime的2016-10-10 00:00:00改成2016-10-10,00:00:00
                            else:
                                sf=[]
                                for el in ele.split(','):
                                    if ele.split(',')[3] == el:
                                        sf.append(','.join((ele.split(',')[3]).split(' ')))
                                    else:
                                        sf.append(el)
                                wfile.write(','.join(sf)[:-2] + '\n')
                 
    except:
        with open('/Users/Jackie/Desktop/1107/ETL.txt','w') as here3:
            here3.write(u'ETL exception'+u'\n')
            here3.write(str(sys.stderr)+u'\n')
            here3.write(str(sys.exc_info()[0])+u'\n')
            here3.write(str(sys.exc_info()[1])+u'\n')
            here3.write(str(sys.exc_info()[2])+u'\n')
                    
def direct_add():
    """
    這個函數要做的只是把剛剛整理好的資料，
    因為有些VD的紀錄裡有一種或兩種方向或是根本沒指定方向，
    全部歸納成只有一種方向，並在檔案名稱上加入方向，
    東西南北就是EWSN，未指定就是U。
    
    """
    try:
        # create 'done' folder if not exist.
        if not os.path.exists('/Users/Jackie/Desktop/1107/done'):
            os.makedirs('/Users/Jackie/Desktop/1107/done')
        # from 'clean' folder chose file that is csv.
        files=[]
        for f in os.listdir('/Users/Jackie/Desktop/1107/clean/'):
            if os.path.isfile('/Users/Jackie/Desktop/1107/clean/'+f):
                files.append(f)
        for f in files:
            if '.csv' in f:
                # empty list to temp store data and seperate by direct
                Ntemp=[]
                Stemp=[]
                Etemp=[]
                Wtemp=[]
                Utemp=[]
                ff=[]
                with io.open('/Users/Jackie/Desktop/1107/clean/'+f,'r',encoding='utf-8')as rfile:
                    for line in rfile:
                        ff.append(line)
                    for ele in ff[1:]:
                        #  有些資料可能會寫成'往北''往南'或'向北''向南'，但是都一樣方向
                        if (ele.split(',')[2] =='往北')or(ele.split(',')[2] =='向北')or(ele.split(',')[2] =='北'):
                            Ntemp.append(ele)
                        elif (ele.split(',')[2] =='往南')or(ele.split(',')[2] =='向南')or(ele.split(',')[2] =='南'):
                            Stemp.append(ele)
                        elif (ele.split(',')[2] =='往東')or(ele.split(',')[2] =='向東')or(ele.split(',')[2] =='東'):
                            Etemp.append(ele)
                        elif (ele.split(',')[2] =='往西')or(ele.split(',')[2] =='向西')or(ele.split(',')[2] =='西'):
                            Wtemp.append(ele)
                        elif (ele.split(',')[2] =='未指定')or(ele.split(',')[2] =='正向放置'):
                            Utemp.append(ele) 
                # 這裡的寫法是因為空list的bool值是false，有值的[]是true，以此去判斷。
                if Ntemp:
                    with io.open('/Users/Jackie/Desktop/1107/done/'+'N'+f,'w',encoding='utf-8') as nfile:
                        nfile.write(ff[0])
                        for ele in Ntemp:
                            nfile.write(ele)
                if Stemp:
                    with io.open('/Users/Jackie/Desktop/1107/done/'+'S'+f,'w',encoding='utf-8') as sfile:
                        sfile.write(ff[0])
                        for ele in Stemp:
                            sfile.write(ele)
                if  Etemp:
                    with io.open('/Users/Jackie/Desktop/1107/done/'+'E'+f,'w',encoding='utf-8') as efile:
                        efile.write(ff[0])
                        for ele in Etemp:
                            efile.write(ele)
                if Wtemp:
                    with io.open('/Users/Jackie/Desktop/1107/done/'+'W'+f,'w',encoding='utf-8') as wfile:
                        wfile.write(ff[0])
                        for ele in Wtemp:
                            wfile.write(ele)
                if Utemp:
                    with io.open('/Users/Jackie/Desktop/1107/done/'+'U'+f,'w',encoding='utf-8') as ufile:
                        ufile.write(ff[0])
                        for ele in Utemp:
                            ufile.write(ele)
    except:
        with open('/Users/Jackie/Desktop/1107/direct_add.txt','w') as here3:
            here3.write(u'direct_add exception'+u'\n')
            here3.write(str(sys.stderr)+u'\n')
            here3.write(str(sys.exc_info()[0])+u'\n')
            here3.write(str(sys.exc_info()[1])+u'\n')
            here3.write(str(sys.exc_info()[2])+u'\n')
# Out:
# 2016/11/21_13:42:39

# %%
def create_table():
    try:
        conn = mysql.connector.connect(host='localhost',
                                       database='for1121',
                                       user='root',
                                       password='apple')
        cursor = conn.cursor()
        filelist = []
        
        for roots,dirs,files in os.walk('/Users/Jackie/Desktop/1114/20161121notinDB/'):
            for ele in files:
                if '.csv' in ele:
                    filelist.append(ele)
        replace2 = []
        for f in filelist:
            #利用正規表達式，從檔名去找table名
            match = re.findall('[A-Z0-9]+', f)
            tablename = str(match[0])
            replace2.append(tablename)
        for ele in replace2:         
            query = ('''create table {r} (EQIPnumber varchar(255),location varchar(255),direct varchar(25),
            YMD varchar(25),hour varchar(25),laneNumber int(2),addTotal double,15Total double,truckflow double,
            carflow double,scooterflow double,avgspeed double,avgPercent double,avgCarSpace double);'''.format(r=ele))
            cursor.execute(query)
            conn.commit()
    except Error as e:
        print(e)
        with open('/Users/Jackie/Desktop/1114/20161121notinDB/create.txt','w') as here3:
            here3.write(u'create exception'+u'\n')
            here3.write(str(sys.stderr)+u'\n')
            here3.write(str(sys.exc_info()[0])+u'\n')
            here3.write(str(sys.exc_info()[1])+u'\n')
            here3.write(str(sys.exc_info()[2])+u'\n')
    finally:
        cursor.close()
        conn.close()

# %%
create_table()
# Out:
# 1050 (42S01): Table 'ev2110c0' already exists

# %%
def insert_data():
    """
    主要是使用連結資料庫的第三方套件mysql.connector，
    以python去對資料庫做連結，在利用for loop把資料insert到正確的table下。
    
    """
    try:
#     連結資料庫的第三方套件
        cnx = mysql.connector.connect(user='root', password='apple', database='1107vd')
        cursor = cnx.cursor()
        files = []
        for f in os.listdir('/Users/Jackie/Desktop/1107/done/'):
            if os.path.isfile('/Users/Jackie/Desktop/1107/done/' + f):
                files.append(f)
        replace2 = []
        for f in files:
            if '.csv' in f:
                #利用正規表達式，從檔名去找table名
                match = re.findall('[A-Z0-9]+', f)
                tablename = str(match[0])
                # 讀取要寫入的檔案
                with io.open('/Users/Jackie/Desktop/1107/done/' + f, 'r', encoding='utf-8') as rcsv:
                    content = []
                    for line in rcsv:
                        content.append(line)
                    # 不要欄位名稱，所以要先將內容放在一個list，在取資料時，直接放棄第一筆[1:]
                    for element in content[1:]:
                        #不需要第一行標題 [1:]
                        #先用list再轉成tuple
                        mylist=[tablename,]
                        for ele in element.split(','):
                            mylist.append(str(ele).strip())
                        #轉成tuple
                        mytuple = tuple(mylist)
                        replace2.append(mytuple) 
        #這裡要注意的是'{r[1]}','{r[2]}'...等等到r5要加引號是因為在query時就要加''號，因為'00:00:00'沒加''會出錯！！！
        for ele in replace2:         
            query = ('''insert into {r[0]} (EQIPnumber,location,direct,YMD,hour,laneNumber,addTotal,15Total,
        truckflow,carflow,scooterflow,avgspeed,avgPercent,avgCarSpace)values
        ('{r[1]}','{r[2]}','{r[3]}','{r[4]}','{r[5]}',{r[6]},{r[7]},{r[8]},
        {r[9]},{r[10]},{r[11]},{r[12]},{r[13]},{r[14]});'''.format(r=ele))
            cursor.execute(query)
            cnx.commit()
        cursor.close()
        cnx.close()
    except:
        with open('/Users/Jackie/Desktop/1107/insert_data.txt','w') as here3:
            here3.write(u'insert_data exception'+u'\n')
            here3.write(str(sys.stderr)+u'\n')
            here3.write(str(sys.exc_info()[0])+u'\n')
            here3.write(str(sys.exc_info()[1])+u'\n')
            here3.write(str(sys.exc_info()[2])+u'\n')

# %%
ETL()
direct_add()


cs = time.strftime('%Y/%m/%d_%H:%M:%S',time.localtime())
print cs
# 存粹看運算時間
# Out:
# 2016/11/08_12:25:31

# %%
insert_data()

# %%
cs = time.strftime('%Y/%m/%d_%H:%M:%S',time.localtime())
print cs
# Out:
# 2016/11/08_13:53:21

# %%
#檢查data的內容！


try:
    # create 'done' folder if not exist.
    if not os.path.exists('/Users/Jackie/Desktop/1107/done'):
        os.makedirs('/Users/Jackie/Desktop/1107/done')
    # from 'clean' folder chose file that is csv.
    files=[]
    for f in os.listdir('/Users/Jackie/Desktop/1107/clean/'):
        if os.path.isfile('/Users/Jackie/Desktop/1107/clean/'+f):
            files.append(f)
    direct=[]
    for f in files:
        if '.csv' in f:
            print f
            # empty list to temp store data and seperate by direct
            ff=[]
            with io.open('/Users/Jackie/Desktop/1107/clean/'+f,'r',encoding='utf-8') as rfile:
                for line in rfile:
                    ff.append(line)
            print ff[1:][0]      
        #                 for ele in ff[1:]:
        #                     #  有些資料可能會寫成'往北''往南'或'向北''向南'，但是都一樣方向
        #                     ele.split(',')[2]
#     print direct[0]
                           
except:
    with open('/Users/Jackie/Desktop/1107/direct_add.txt','w') as here3:
        here3.write(u'direct_add exception'+u'\n')
        here3.write(str(sys.stderr)+u'\n')
        here3.write(str(sys.exc_info()[0])+u'\n')
        here3.write(str(sys.exc_info()[1])+u'\n')
        here3.write(str(sys.exc_info()[2])+u'\n')
# Out:
# V6120C0.csv
# V6120C0,市民麥二,正向放置,2016-04-01,00:00:00,2,901.0,1101.5,401.0,500.0,0.0,44.65184,6.7749996,88.78999
#
# V6121A0.csv
# V6121A0,堤頂上匝道,正向放置,2016-04-01,00:00:00,1,49.0,49.0,0.0,49.0,0.0,47.410004,0.53,161.0
#
# V6130C0.csv
# V6130C0,麥二舊宗,正向放置,2016-04-01,00:00:00,2,668.0,668.0,0.0,668.0,0.0,64.3553,2.85,109.535
#
# V6140C0.csv
# V6140C0,麥二舊宗,正向放置,2016-04-01,00:00:00,2,74.0,74.5,1.0,73.0,0.0,47.998375,0.65,148.625
#
# V6140C1.csv
# V6140C1,麥二舊宗,正向放置,2016-04-01,00:00:00,2,422.0,422.0,0.0,422.0,0.0,73.83033,1.515,135.18
#
# V6141E0.csv
# V6141E0,堤頂上匝道入口,正向放置,2016-04-01,00:00:00,1,93.0,101.5,17.0,76.0,0.0,56.880005,1.22,109.3
#
# V6150C0.csv
# V6150C0,堤頂舊宗,正向放置,2016-04-01,00:00:00,2,394.0,394.0,0.0,394.0,0.0,78.17432,1.335,133.67
#
# V6150C1.csv
# V6150C1,堤頂舊宗,正向放置,2016-04-01,00:00:00,2,367.0,367.0,0.0,367.0,0.0,73.48883,1.24,123.265
#
# V6151C0.csv
# V6151C0,舊宗路出城上匝道入口,正向放置,2016-04-01,00:00:00,1,106.0,106.5,1.0,105.0,0.0,64.41,1.58,100.52
#
# V6160C0.csv
# V6160C0,舊宗經貿,正向放置,2016-04-01,00:00:00,2,500.0,500.0,0.0,500.0,0.0,62.38036,1.665,116.835
#
# V6160C1.csv
# V6160C1,舊宗經貿,正向放置,2016-04-01,00:00:00,2,494.0,571.5,155.0,339.0,0.0,47.67405,3.195,130.575
#
# V6330G7.csv
# V6330G7,經貿舊宗,正向放置,2016-04-01,00:00:00,2,396.0,396.5,1.0,395.0,0.0,59.49232,1.69,132.14
#
# V6330G8.csv
# V6330G8,經貿舊宗,正向放置,2016-04-01,00:00:00,2,439.0,439.0,0.0,439.0,0.0,61.62387,1.575,120.815
#
# V6340G0.csv
# V6340G0,舊宗堤頂,正向放置,2016-04-01,00:00:00,2,378.0,413.5,71.0,307.0,0.0,70.04476,1.15,135.675
#
# V6340G1.csv
# V6340G1,舊宗堤頂,正向放置,2016-04-01,00:00:00,2,309.0,309.0,0.0,309.0,0.0,78.60564,1.115,125.3
#
# V6350G0.csv
# V6350G0,堤頂舊宗,正向放置,2016-04-01,00:00:00,2,288.0,288.5,1.0,287.0,0.0,76.87153,1.165,131.79001
#
# V6360G0.csv
# V6360G0,舊宗麥二,正向放置,2016-04-01,00:00:00,2,627.0,627.5,1.0,626.0,0.0,69.53001,2.335,104.39
#
# V6360G1.csv
# V6360G1,舊宗麥二,正向放置,2016-04-01,00:00:00,2,412.0,412.0,0.0,412.0,0.0,62.158833,1.665,119.36
#
# V6380E0.csv
# V6380E0,正氣橋接基隆路出口,正向放置,2016-04-01,00:00:00,2,580.0,580.0,0.0,580.0,0.0,50.578793,2.25,112.255005
#
# V7010A0.csv
# V7010A0,環東出城接麥二橋,正向放置,2016-04-01,00:00:00,2,796.0,797.5,3.0,793.0,0.0,55.428555,3.37,99.369995
#
# V7230E0.csv
# V7230E0,麥二進城接正氣橋,正向放置,2016-04-01,00:00:00,2,450.0,450.0,0.0,450.0,0.0,58.282093,1.7800001,110.149994
#
# VJERC40.csv
# VJERC40,基隆路一段172巷口(門架式),往南,2016-04-01,00:00:00,2,541.0,606.61017,111.0,430.0,0.0,51.517635,2.515,125.395
#
# VJERC50.csv
# VJERC50,基隆路-忠孝東,往南,正向放置,2016-04-01,00:00:00,2,476.0,479.0,6.0,470.0,0.0,55.206825,1.99,170.34
#
# VJERC51.csv
# VJERC51,基隆路-忠孝東,往南,正向放置,2016-04-01,00:00:00,2,468.0,468.5,1.0,467.0,0.0,75.70897,1.31,168.62
#
# VJERC52.csv
# VJERC52,基隆路-忠孝東,往南,正向放置,2016-04-01,00:00:00,2,447.0,449.5,5.0,442.0,0.0,71.25939,1.625,183.32501
#
# VJVRL10.csv
# VJVRL10,基隆路-松隆路,往北,正向放置,2016-04-01,00:00:00,2,468.0,472.0,8.0,460.0,0.0,37.180595,3.805,184.29001
#
# VJVRL11.csv
# VJVRL11,基隆路-松隆路,往北,正向放置,2016-04-01,00:00:00,2,494.0,498.5,9.0,485.0,0.0,70.69968,1.6400001,173.595
#
# VJVRL40.csv
# VJVRL40,基隆路(永吉-松隆)-基隆路一段松山高中旁既設CMS(062)桿,未指定,2016-04-01,00:00:00,3,903.0,1030.5,255.0,648.0,0.0,35.68661,3.4099998,101.71334
#
# VL9SB00.csv
# VL9SB00,基隆路一段8號前,往北,2016-04-01,00:00:00,4,369.0,394.57623,38.0,331.0,0.0,42.46062,1.5475001,0.0
#
# VLKSH00.csv
# VLKSH00,環東大道(南京東至永吉)-正氣橋門型架(往市民大道),北,2016-04-01,00:00:00,3,1022.0,1048.0,52.0,970.0,0.0,75.4889,2.16,0.0
#
# VM010A2.csv
# VM010A2,復興北路隧道東側隧道頂板二車道主線0K+740公尺處,正向放置,2016-04-01,00:00:00,2,64.0,64.0,0.0,64.0,0.0,70.75109,0.385,204.815
#
# VM210E2.csv
# VM210E2,復興北路隧道西側隧道頂板二車道主線0K+740公尺處,正向放置,2016-04-01,00:00:00,2,117.0,125.0,16.0,101.0,0.0,79.86752,0.55,164.685
#
# VMLXB00.csv
# VMLXB00,向陽路168號(首都客運停車場右側),往北,2016-04-01,00:00:00,2,82.0,203.07693,12.0,70.0,0.0,53.096222,1.3,0.0
#
# VNXPC60.csv
# VNXPC60,民權東路四段新中街口往西約45M處,往西,2016-04-01,00:00:00,3,280.0,302.0,44.0,236.0,0.0,60.965145,1.23,0.19333334
#
# VNZ4641.csv
# VNZ4641,三重路69號（南湖大橋-經貿二路）,往南,2016-04-01,00:00:00,2,168.0,172.0,8.0,160.0,0.0,20.475357,2.61,0.03
#
# VP5QG20.csv
# VP5QG20,民權東路四段民權公園出入口右側,往東,2016-04-01,00:00:00,3,350.0,374.99997,0.0,350.0,0.0,44.5488,1.4233335,131.31334
#
# VPBTD70.csv
# VPBTD70,舊宗路一段與舊宗路一段150巷口,北,2016-04-01,00:00:00,4,242.0,252.5,21.0,221.0,0.0,53.051033,0.96000004,0.0
#
# VPMSV40.csv
# VPMSV40,堤頂大道二段內湖污水處理場停車場出口右側,往北,2016-04-01,00:00:00,3,468.0,501.42856,0.0,468.0,0.0,56.22658,1.2233334,127.14333
#
# VPWMA00.csv
# VPWMA00,復興北路495號前(路燈桿),北,2016-04-01,00:00:00,1,80.0,81.5,3.0,77.0,0.0,59.48,1.02,0.0
#
# VQ6WK40.csv
# VQ6WK40,成功路2段312巷(單號)對面,往北,2016-04-01,00:00:00,2,349.0,367.11865,24.0,325.0,0.0,54.675503,2.155,0.0
#
# VQEUU60.csv
# VQEUU60,民權東路六段(中天電視對面),往西,2016-04-01,00:00:00,2,411.0,439.32202,42.0,369.0,0.0,57.83861,2.01,178.61
#
# VQKWL00.csv
# VQKWL00,成功路二段380號旁,往北,2016-04-01,00:00:00,2,345.0,358.98303,16.0,329.0,0.0,49.853046,2.26,0.0
#
# VQKWL40.csv
# VQKWL40,成功路二段373號前,往北,2016-04-01,00:00:00,2,161.0,532.1053,15.0,146.0,0.0,58.399067,2.845,0.0
#
# VQKWL60.csv
# VQKWL60,民權東路六段(防災科學教育館對面),往西,2016-04-01,00:00:00,2,152.0,161.5,19.0,133.0,0.0,60.459217,0.75,236.86499
#
# VQKWL61.csv
# VQKWL61,民權東路六段203巷口往西30M,向西,2016-04-01,00:00:00,2,64.0,66.10169,2.0,62.0,0.0,14.578906,0.55,244.19
#
# VQRTE00.csv
# VQRTE00,舊宗路二段121巷口左側人行道上,往北,2016-04-01,00:00:00,2,251.0,272.03387,33.0,218.0,0.0,55.830475,1.48,211.97
#
# VRKQZ40.csv
# VRKQZ40,基湖路122號-158號(煙波巴洛克大樓對面人行道),往北,2016-04-01,00:00:00,1,61.0,63.55932,3.0,58.0,0.0,36.89,1.05,0.0
#
# VRPSV00.csv
# VRPSV00,堤頂大道二段與舊宗路二段路口槽化島,往北,2016-04-01,00:00:00,3,283.0,305.35712,4.0,279.0,0.0,47.487106,1.0233333,139.08
#
# VRPSV70.csv
# VRPSV70,舊宗路二段213巷口對面槽化島上,往北,2016-04-01,00:00:00,2,184.0,187.5,7.0,177.0,0.0,47.60706,0.96000004,226.025
#
# VS6TI00.csv
# VS6TI00,瑞光路295號前,往北,2016-04-01,00:00:00,1,108.0,122.0339,24.0,84.0,0.0,35.15,2.26,218.71
#
# VS7SN60.csv
# VS7SN60,堤頂大道二段251號前,未指定,2016-04-01,00:00:00,2,215.0,219.0,8.0,207.0,0.0,73.50604,1.0799999,0.0
#
# VS9TE00.csv
# VS9TE00,港墘路219號前,往北,2016-04-01,00:00:00,1,31.0,31.0,0.0,31.0,0.0,27.84,0.45,249.07
#
# VSDPM60.csv
# VSDPM60,樂群一路與基湖路口往西約140公尺(堤防里程15K+750),往西,2016-04-01,00:00:00,1,16.0,16.0,0.0,16.0,0.0,70.0,0.23,250.0
#
# VSEMA00.csv
# VSEMA00,大直橋(明水路上方)(附掛閉路電視桿),往北,2016-04-01,00:00:00,3,201.0,215.35713,0.0,201.0,0.0,59.31179,0.7166667,151.19666
#
# VSEMV60.csv
# VSEMV60,明水路417號前,往西,2016-04-01,00:00:00,1,181.0,184.0678,0.0,181.0,0.0,66.65,1.82,0.0
#
# VSGLN60.csv
# VSGLN60,明水路大直橋往西約130M處,往西,2016-04-01,00:00:00,1,142.0,144.91525,1.0,141.0,0.0,58.42,1.54,0.0
#
# VSGRX60.csv
# VSGRX60,堤頂大道二段177號前,往西,2016-04-01,00:00:00,2,283.0,303.2143,0.0,283.0,0.0,49.21841,1.3,131.975
#
# VSHZU60.csv
# VSHZU60,成功路(康湖路-康寧路三段)-成功路5段康湖路口前CMS桿(4x5字CMS),往西,2016-04-01,00:00:00,2,207.0,244.57626,67.0,140.0,0.0,44.344303,1.23,56.93
#
# VSKTL00.csv
# VSKTL00,港墘路149號對面人行道上,往北,2016-04-01,00:00:00,2,341.0,350.5,19.0,322.0,0.0,103.40621,1.81,194.4
#
# VSM4D60.csv
# VSM4D60,1+760北側車道(二號隧道內),西,2016-04-01,00:00:00,4,149.0,85.58153,0.0,84.0,65.0,56.203625,4.6975,40.9225
#
# VSM4D61.csv
# VSM4D61,1+360北側車道(二號隧道內),西,2016-04-01,01:00:00,4,14.0,8.0,0.0,8.0,6.0,72.50143,0.055,3.855
#
# VSNRE00.csv
# VSNRE00,瑞光路390號車道出口對面人行道上,往北,2016-04-01,00:00:00,1,83.0,84.0,2.0,81.0,0.0,34.36,1.07,230.87
#
# VSNVA60.csv
# VSNVA60,內湖路(港墘路-文德路)-文德路15號路燈桿(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,2,187.0,212.54236,44.0,143.0,0.0,36.01294,1.4250001,109.42
#
# VSPRA40.csv
# VSPRA40,基湖路39號前,往北,2016-04-02,16:00:00,1,166.0,182.18181,2.0,164.0,0.0,40.41,0.95,21.15
#
# VSPRA60.csv
# VSPRA60,堤頂大道二段285號前,往西,2016-04-01,00:00:00,2,205.0,219.64285,0.0,205.0,0.0,57.641605,1.0,144.04001
#
# VSQVZ20.csv
# VSQVZ20,文德路(文德路-金龍路)-文德路內湖高中門口前路燈桿(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,2,1567.0,1993.6455,610.0,958.0,-1.0,36.845093,6.835,66.545
#
# VSQYA00.csv
# VSQYA00,金湖路268號前,往西,2016-04-01,00:00:00,1,805.0,810.0,10.0,795.0,0.0,50.39,7.72,0.4
#
# VSSWC60.csv
# VSSWC60,成功路(文德路-金龍路)-成功路3段152號前路燈桿(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,2,337.0,402.5,131.0,206.0,0.0,47.03255,1.96,133.5
#
# VSWMR40.csv
# VSWMR40,北安路520號對面人行道,往北,2016-04-01,00:00:00,2,388.0,416.25,1.0,387.0,0.0,46.796906,0.385,30.54
#
# VSXTK20.csv
# VSXTK20,內湖路(港墘路-文德路)-港墘捷運站2號出口前號誌桿,未指定,2016-04-01,00:00:00,2,285.0,311.5,53.0,232.0,0.0,45.19621,1.275,126.45
#
# VT5QV00.csv
# VT5QV00,堤頂大道二段344號對面人行道,往北,2016-04-01,00:00:00,2,150.0,156.61017,8.0,142.0,0.0,44.23467,1.0600001,235.135
#
# VT8SZ60.csv
# VT8SZ60,內湖路(基湖路-港墘路)-內湖路1段609號路燈桿(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,2,207.0,212.5,11.0,196.0,0.0,36.115215,1.0799999,118.21001
#
# VT9NN00.csv
# VT9NN00,明水路604號對面人行道上,往北,2016-04-01,00:00:00,2,63.0,67.62712,7.0,56.0,0.0,52.3,0.515,0.0
#
# VTEZS61.csv
# VTEZS61,0+535北側車道(一號隧道內),西,2016-04-01,00:00:00,4,99.0,96.0,0.0,96.0,3.0,61.820004,0.4375,20.8175
#
# VTHRR20.csv
# VTHRR20,內湖路(基湖路-港墘路)-西湖捷運站2號出口前路燈桿(TC箱旁),未指定,2016-04-01,00:00:00,2,331.0,357.4576,41.0,290.0,0.0,38.33849,1.82,112.009995
#
# VTVXH20.csv
# VTVXH20,成功路(文德路-金龍路)-成功路4段147號星巴克前路燈桿(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,2,328.0,375.7627,83.0,245.0,0.0,42.040367,1.695,109.405
#
# VTXQJ20.csv
# VTXQJ20,內湖路(北安路-基湖路)-文湖街對面(捷運柱號0218)路燈桿(台電變電箱旁),未指定,2016-04-01,00:00:00,3,705.0,771.0,132.0,573.0,0.0,41.322807,2.0933332,94.756676
#
# VTXQL00.csv
# VTXQL00,堤頂大道二段489-501號中間空地前,往北,2016-04-01,00:00:00,2,129.0,138.21428,0.0,129.0,0.0,57.879845,0.665,163.375
#
# VTYXQ60.csv
# VTYXQ60,成功路(金龍路-康湖路)-成功路4段294巷口路燈桿(捷運柱號0611)(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,2,149.0,168.81355,34.0,115.0,0.0,44.661545,0.57500005,118.49
#
# VTZY920.csv
# VTZY920,成功路(金龍路-康湖路)-成功路4段323巷口路燈桿(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,2,271.0,285.2542,19.0,252.0,0.0,38.251442,2.405,122.09
#
# VU5QC60.csv
# VU5QC60,內湖路(北安路-基湖路)-內湖路1段59號加油站前路燈桿(已附掛市警局CCTV),未指定,2016-04-01,00:00:00,4,97.0,97.5,1.0,96.0,0.0,33.74794,0.0075,71.6075
#
# VU8P760.csv
# VU8P760,北安路813-1號前燈桿,北,2016-04-01,00:00:00,4,505.0,513.0,16.0,489.0,0.0,61.90206,1.6025,0.0
